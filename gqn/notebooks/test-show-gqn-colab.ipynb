# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! pip install tensorboardX
! pip install pytorch-ignite
% cd /content/gdrive/My\ Drive/Colab\ Notebooks/generative-query-network-pytorch-master/
import torch
from tqdm import tqdm
from gqn import GenerativeQueryNetwork, partition, Annealer
import torch
import torch.nn as nn
import random
from shepardmetzler import ShepardMetzler
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from collections import OrderedDict
def deterministic_partition(images, viewpoints, indices):
    """
    Partition batch into context and query sets.
    :param images
    :param viewpoints
    :return: context images, context viewpoint, query image, query viewpoint
    """
    # Maximum number of context points to use
    _, b, m, *x_dims = images.shape
    _, b, m, *v_dims = viewpoints.shape

    # "Squeeze" the batch dimension
    images = images.view((-1, m, *x_dims))
    viewpoints = viewpoints.view((-1, m, *v_dims))

    # Partition into context and query sets
    context_idx, query_idx = indices[:-1], indices[-1]

    x, v = images[:, context_idx], viewpoints[:, context_idx]
    x_q, v_q = images[:, query_idx], viewpoints[:, query_idx]

    return x, v, x_q, v_q
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (46.1.3)
# Requirement already satisfied: pytorch-ignite in /usr/local/lib/python3.6/dist-packages (0.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pytorch-ignite) (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->pytorch-ignite) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->pytorch-ignite) (1.18.3)
# /content/gdrive/My Drive/Colab Notebooks/generative-query-network-pytorch-master

# %%
dataset = ShepardMetzler("/content/gdrive/My Drive/FilePortal/gqn/shepard_metzler_5_parts/", fraction=0.1) ## <= Choose your data location
loader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
# Pick a scene to visualise
scene_id = 0

# Load data
x, v = next(iter(loader))
x_, v_ = x.squeeze(0), v.squeeze(0)

# Sample a set of views
n_context = 7 + 1
indices = random.sample([i for i in range(v_.size(1))], n_context)

# Seperate into context and query sets
x_c, v_c, x_q, v_q = deterministic_partition(x, v, indices)

# Visualise context and query images
f, axarr = plt.subplots(1, 15, figsize=(20, 7))
for i, ax in enumerate(axarr.flat):
    # Move channel dimension to end
    ax.imshow(x_[scene_id][i].permute(1, 2, 0))
    
    if i == indices[-1]:
        ax.set_title("Query", color="magenta")
    elif i in indices[:-1]:
        ax.set_title("Context", color="green")
    else:
        ax.set_title("Unused", color="grey")
    
    ax.axis("off")

# %%
import os
import numpy as np
import matplotlib.animation as animation
checkpoint_dir = os.listdir('./pretrained/')
#checkpoint_dir = np.sort(checkpoint_dir)
list(checkpoint_dir), len(checkpoint_dir)
# Out:
# (['checkpoint_checkpoint_2260.pth',
#   'checkpoint_checkpoint_4520.pth',
#   'checkpoint_checkpoint_6780.pth',
#   'checkpoint_checkpoint_9040.pth',
#   'checkpoint_checkpoint_11300.pth',
#   'checkpoint_checkpoint_13560.pth',
#   'checkpoint_checkpoint_15820.pth',
#   'checkpoint_checkpoint_18080.pth',
#   'checkpoint_checkpoint_20340.pth',
#   'checkpoint_checkpoint_22600.pth',
#   'checkpoint_checkpoint_24860.pth',
#   'checkpoint_checkpoint_27120.pth',
#   'checkpoint_checkpoint_29380.pth',
#   'checkpoint_checkpoint_31640.pth',
#   'checkpoint_checkpoint_33900.pth',
#   'checkpoint_checkpoint_36160.pth',
#   'checkpoint_checkpoint_38420.pth',
#   'checkpoint_checkpoint_40680.pth',
#   'checkpoint_checkpoint_42940.pth',
#   'checkpoint_checkpoint_45200.pth',
#   'checkpoint_checkpoint_47460.pth',
#   'checkpoint_checkpoint_49720.pth',
#   'checkpoint_checkpoint_51980.pth',
#   'checkpoint_checkpoint_54240.pth',
#   'checkpoint_checkpoint_56500.pth',
#   'checkpoint_checkpoint_58760.pth',
#   'checkpoint_checkpoint_61020.pth',
#   'checkpoint_checkpoint_63280.pth',
#   'checkpoint_checkpoint_65540.pth',
#   'checkpoint_checkpoint_67800.pth',
#   'checkpoint_checkpoint_70060.pth',
#   'checkpoint_checkpoint_72320.pth',
#   'checkpoint_checkpoint_74580.pth',
#   'checkpoint_checkpoint_76840.pth',
#   'checkpoint_checkpoint_79100.pth',
#   'checkpoint_checkpoint_81360.pth',
#   'checkpoint_checkpoint_83620.pth',
#   'checkpoint_checkpoint_85880.pth',
#   'checkpoint_checkpoint_88140.pth',
#   'checkpoint_checkpoint_90400.pth',
#   'checkpoint_checkpoint_92660.pth',
#   'checkpoint_checkpoint_94920.pth',
#   'checkpoint_checkpoint_97180.pth',
#   'checkpoint_checkpoint_99440.pth',
#   'checkpoint_checkpoint_101700.pth',
#   'checkpoint_checkpoint_103960.pth',
#   'checkpoint_checkpoint_106220.pth',
#   'checkpoint_checkpoint_108480.pth',
#   'checkpoint_checkpoint_110740.pth',
#   'checkpoint_checkpoint_113000.pth',
#   'checkpoint_checkpoint_115260.pth',
#   'checkpoint_checkpoint_117520.pth',
#   'checkpoint_checkpoint_119780.pth',
#   'checkpoint_checkpoint_122040.pth'],
#  54)

# %%
ims = []
batch_size, n_views, c, h, w = x_c.shape
for checkpoint in tqdm(checkpoint_dir):
    model = GenerativeQueryNetwork(x_dim=3, v_dim=7, r_dim=256, h_dim=128, z_dim=64, L=8)
    state_dict = torch.load('./pretrained/' + checkpoint, map_location=torch.device('cpu'))
    state_dict = state_dict['model']
    new_state_dict = OrderedDict()
    for k, v in (state_dict.items()):
        name = k[7:]
        new_state_dict[name] = v
    model.load_state_dict(new_state_dict)
    model.eval()

    f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 7))
    phi = model.representation(x_c[scene_id], v_c[scene_id])
    r = torch.sum(phi, dim=0)
    x_mu = model.generator.sample((h, w), v_q[scene_id].unsqueeze(0), r)

    ax1.imshow(x_q[scene_id].data.permute(1, 2, 0))
    ax1.set_title("Query image")
    ax1.axis("off")

    ax2.imshow(x_mu.squeeze(0).data.permute(1, 2, 0))
    ax2.set_title("Reconstruction")
    ax2.axis("off")

    ax3.imshow(r.data.view(16, 16))
    ax3.set_title("Representation")
    ax3.axis("off")

    plt.savefig('./test-show/' + checkpoint[:-4] + '.png')
# Out:
#  37%|███▋      | 20/54 [01:22<02:39,  4.69s/it]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# 100%|██████████| 54/54 [03:01<00:00,  3.36s/it]
