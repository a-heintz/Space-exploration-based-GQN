# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
% cd /content/drive/My Drive/FilePortal/
% mkdir gqn
! gsutil -m cp -R gs://gqn-dataset/shepard_metzler_5_parts /content/drive/My\ Drive/FilePortal/gqn/
% cd /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/train/
% mkdir {001..900}
% cd /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/test/
% mkdir {001..100}
# %%shell
cd /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/train
for folder in {001..900}
do
echo "copying $folder"
cp $folder-of-900.tfrecord /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/train/$folder/
done
# %%shell
cd /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/test
for folder in {001..100}
do
echo "copying $folder"
cp $folder-of-100.tfrecord /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/test/$folder/
done
# Out:
# /content/drive/My Drive/FilePortal/gqn
# /content/drive/My Drive/FilePortal/gqn/shepard_metzler_5_parts/train

# %%
! python /content/drive/My\ Drive/Colab\ Notebooks/generative-query-network-pytorch-master/scripts/tfrecord-converter.py /content/drive/My\ Drive/FilePortal/gqn shepard_metzler_5_parts -b 12 -m "train"

# %%
! python /content/drive/My\ Drive/Colab\ Notebooks/generative-query-network-pytorch-master/scripts/tfrecord-converter.py /content/drive/My\ Drive/FilePortal/gqn shepard_metzler_5_parts -b 12 -m "test"

# %%
% rm /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/test/***/*.tfrecord
% rm /content/drive/My\ Drive/FilePortal/gqn/shepard_metzler_5_parts/train/***/*.tfrecord
