# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
! pip install tensorboardX
! pip install pytorch-ignite
% cd /content/gdrive/My\ Drive/Colab\ Notebooks/generative-query-network-pytorch-master/
# Out:
# ...
#      |████████████████████████████████| 204kB 8.2MB/s
# ...
#      |████████████████████████████████| 112kB 9.3MB/s
# ...
# /content/gdrive/My Drive/Colab Notebooks/generative-query-network-pytorch-master

# %%
! python ./run-gqn.py --resume_training=True --n_epochs=250 --batch_size=6 --data_parallel=True --workers=4 --pretrained_path=./pretrained/ --fraction=0.2 --data_dir=../../FilePortal/gqn/shepard_metzler_5_parts/
# Out:
# device:  cuda
# Creating GQN Model
# Creating train dataset
# Creating test dataset
# train set: 13560
# test set: 3340
# /usr/local/lib/python3.6/dist-packages/ignite/handlers/checkpoint.py:369: UserWarning: Argument save_interval is deprecated and should be None. Please, use events filtering instead, e.g. Events.ITERATION_STARTED(every=1000)
#   warnings.warn(msg)
# Resuming Training at Epoch  44 ... Iteration  99440
# Epoch [55/250]:  86% 1951/2260 [46:59<07:51,  1.53s/it, elbo=-6.99e+3, kl=28.6, mu=5e-6, sigma=0.7]

# %%
  % cd ~/Google Drive/Colab Notebooks/generative-query-network-pytorch-master
